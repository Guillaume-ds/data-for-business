# %% [markdown]
# # Comment apprendre Python - Edition spéciale Julien
#
# Petit guide pour te permettre d'apprendre ce qu'est python et le code en général, avec pour objectif de faire du web-scrapping et une interface web.
#
# > Avant tout, il faut regarder ce <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ"> petit tuto </a> !
#
# ## Plan général
#
# 1. [Qu'est ce que le code, et pourquoi python](#part1)
# 2. [Comment installer et utliser python](#part2)
# 3. [Comment faire du web scrapping](#part3)
# 4. [Comment créer une interface web avec streamlit](#part4)
#
# ## 1 Qu'est ce que le code, et pourquoi python ?
# <a id='part1'></a>
#
# ### 1.1 Qu'est ce que le code ?
#
# [Vidéo "Programming language Guide](https://www.youtube.com/watch?v=2lVDktWK-pc&t=71s) Donne une bonne idée des différents languages qui existent et de leur utilité.
#
# ### 1.2 Les différents domaines de programmation
#
# [Vidéo "la carte de l'informatique"](https://www.youtube.com/watch?v=SzJ46YA_RaA), elle donne une bonne idée des différents champs de la programmation. <br>
# [Articles](https://medium.com/coding-den/fields-of-programming-67e8a0976d4b) sur les différents domaines de programmation.<br>
# [Articles](https://datascientest.com/front-end-vs-back-end) sur la différence entre backend et frontend et de l'intérêt pour le dev d'application (avec d'autres liens internes utiles).<br>
#
# Je mets ça parce que c'est important de comprendre que t'as pas de solution "out of the box".Pour ton projet il faut que tu comprennes comment coder, comment faire du web scrapping et donc la façon dont les data sont présentent en ligne, comment transformer des données et comment développer une application. Tu vas avoir besoin de comprendre quelques notions, dont principalement :
#
# - La structure d'une page web (avec HTML et CSS)
# - Comment marche une API
# - Comment enregistrer et modifier des fichiers à partir du code
#
# Le plus important en code c'est de savoir chercher sur internet. Quand tu comprends pas un truc, épluche google, youtube, [stackoverflow](https://stackoverflow.com) (C'est un forum de codeurs) ... C'est normal de galérer car il n'y a pas de chemin linéaire pour apprendre le code. A chaque étape, tu vas découvrir de nouvelles notions qui s'entremèlent qu'il faut comprendre avant d'avancer, mais il n'y a pas de structure d'apprentissage parfaitement linéaire.
#
# ### 1.3 C'est quoi Python ?
# [Video "What is python? Why is it so popular"](https://www.youtube.com/watch?v=Y8Tko2YC5hA)Intéressant pour comprendre un peu les cas d'usages de python
# [Video why learn python in 2022](https://www.youtube.com/watch?v=UGj0bOYPdCw)Complément à celle d'au dessus
# [Intro rapide au frontend et backend](https://datascientest.com/front-end-vs-back-end)
#
# Le langage de programmation Python a été créé en 1989 par Guido van Rossum, aux Pays-Bas. Le nom Python vient d'un hommage à la série télévisée Monty Python's Flying Circus dont G. van Rossum est fan. La première version publique de ce langage a été publiée en 1991.
#
# Pourquoi python :
#
# Il est multiplateforme. C'est-à-dire qu'il fonctionne sur de nombreux systèmes d'exploitation : Windows, Mac OS X, Linux, Android, iOS, depuis les mini-ordinateurs Raspberry Pi jusqu'aux supercalculateurs.
# Il est gratuit. Vous pouvez l'installer sur autant d'ordinateurs que vous voulez (même sur votre téléphone !).
# C'est un langage de haut niveau. Il demande relativement peu de connaissance sur le fonctionnement d'un ordinateur pour être utilisé.
# C'est un langage interprété. Un script Python n'a pas besoin d'être compilé pour être exécuté, contrairement à des langages comme le C ou le C++.
# Il est orienté objet. C'est-à-dire qu'il est possible de concevoir en Python des entités qui miment celles du monde réel (une cellule, une protéine, un atome, etc.) avec un certain nombre de règles de fonctionnement et d'interactions.
# Il est relativement simple à prendre en main1.
# Enfin, il est très utilisé en bioinformatique et plus généralement en analyse de données.
# Toutes ces caractéristiques font que Python est désormais enseigné dans de nombreuses formations, depuis l'enseignement secondaire jusqu'à l'enseignement supérieur.
#
# ## 2 Comment apprendre python ?
# <a id='part2'></a>
#
# L'avantage de python est le nombre de tutos disponibles, donc tu vas pouvoir trouver plein de trucs en ligne et sur youtube. Je te mets les quelques liens de chaines que j'aime bien en dessous.
#
# **Attention, c'est parfois un peu compliqué de comprendre comment utiliser et exécuter des scripts pythons au début. Normalement les tutos l'expliquent bien, mais sinon demande moi !**
#
# [Tutoriel python - Neural Nine](https://www.youtube.com/watch?v=-eaFKumWT1k&list=PL7yh-TELLS1E6dNCzfQl-NG-KJP3C-4mc) Le tuto fait 10 vidéos et couvre vraiment la base de ce qui est nécessaire. Ca permet pas d'aller bien loin mais c'est un bon début. Il a fait aussi une série "Intermédiaire" qui peut être pas mal, mais pas essentielle pour ce que tu veux faire.
#
# [Tutoriel python - tech with Tim](https://www.youtube.com/watch?v=0VdzZQdaZ28&list=PLzMcBGfZo4-nhWva-6OVh1yKWHBs4o_tv) Tuto niveau intermédiaire qui est utile pour ce que tu veux faire.
#
# Apprends à utiliser pip (cherches sur internet), à installer des packages avec pip (internet), à créer un environnement virtuel (@), et regardes ce qu'est github(t'as deviné, internet!).
#
# >Maintenant que tu as les bases de python, tu as 2 choix : commencer à bosser sur ton projet en galérant un peu (mais c'est plus motivant), ou continuer les cours.
#
# ## 3 Comment faire du web scrapping ?
# <a id='part3'></a>
#
# Je pense que tu peux te lancer dans des cours de web scrapping ce qui fait un bon intermédiare. [Neural Nine](https://www.youtube.com/watch?v=myAFVM7CxWk) a fait d'autres vidéos dessus, mais encore une fois il y a 10 000 ressources. Tu vas probablement galérer un peu parce que tu ne connais ni HTML ni CSS, mais ça s'apprend vite et ça se comprend facilement. Ca peut être pas mal de regarder un tuto, surtout que ça te sera utile pour la suite.
#
# ## 4 Comment créer une application avec Streamlit ?
# <a id='part4'></a>
#
# [Streamlit](https://streamlit.io) est un outil super pratique et puissant pour faire des petites apps comme ça. Il y a pas d'info sur le site, sinon tu trouveras ce qu'il faut sur youtube et sur les forums !
#
# Good luck et hésite pas à me demander si besoin! <br>
# PS: 2 ressources utiles si t'es perdu : <br>
# [Zen of python](https://peps.python.org/pep-0020/)<br>
# [Et là](https://www.youtube.com/watch?v=htgr3pvBr-I)
